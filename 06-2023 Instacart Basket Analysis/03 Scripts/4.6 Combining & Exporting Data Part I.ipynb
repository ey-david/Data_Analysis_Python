# %%
# Import libraries

import pandas as pd
import numpy as np
import os

# %%
#path to project folder
path = '/Users/davidey/06-2023 Instacart Basket Analysis'

# %%
# import the cleaned datasets

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'prods_clean.csv'), index_col = False)

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Prepared Data', 'ords_clean.csv'), index_col = False)

# %%
# import the new dataset

# %%
df_ords_prior = pd.read_csv(os.path.join(path,'02 Data', 'Original Data', 'order_products__prior.csv'), index_col = False)

# %%
#Check the output

# %%
df_ords.head()
# Out:
#    Unnamed: 0  order_id  user_id  user_order_number  orders_day_of_week  \
# 0           0   2539329        1                  1                   2
# 1           1   2398795        1                  2                   3
# 2           2    473747        1                  3                   3
# 3           3   2254736        1                  4                   4
# 4           4    431534        1                  5                   4
#
#    order_hour_of_day  days_since_prior_order
# 0                  8                     NaN
# 1                  7                    15.0
# 2                 12                    21.0
# 3                  7                    29.0
# 4                 15                    28.0

# %%
df_ords.describe()
# Out:
#          Unnamed: 0      order_id       user_id  user_order_number  \
# count  3.421083e+06  3.421083e+06  3.421083e+06       3.421083e+06
# mean   1.710541e+06  1.710542e+06  1.029782e+05       1.715486e+01
# std    9.875817e+05  9.875817e+05  5.953372e+04       1.773316e+01
# min    0.000000e+00  1.000000e+00  1.000000e+00       1.000000e+00
# 25%    8.552705e+05  8.552715e+05  5.139400e+04       5.000000e+00
# 50%    1.710541e+06  1.710542e+06  1.026890e+05       1.100000e+01
# 75%    2.565812e+06  2.565812e+06  1.543850e+05       2.300000e+01
# max    3.421082e+06  3.421083e+06  2.062090e+05       1.000000e+02
#
#        orders_day_of_week  order_hour_of_day  days_since_prior_order
# count        3.421083e+06       3.421083e+06            3.214874e+06
# mean         2.776219e+00       1.345202e+01            1.111484e+01
# std          2.046829e+00       4.226088e+00            9.206737e+00
# min          0.000000e+00       0.000000e+00            0.000000e+00
# ...

# %%
df_ords_prior.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0         2       33120                  1          1
# 1         2       28985                  2          1
# 2         2        9327                  3          0
# 3         2       45918                  4          1
# 4         2       30035                  5          0

# %%
df_ords_prior.shape
# Out:
# (32434489, 4)

# %%
df_ords.shape
# Out:
# (3421083, 7)

# %%
df_ords_prior.describe()
# Out:
#            order_id    product_id  add_to_cart_order     reordered
# count  3.243449e+07  3.243449e+07       3.243449e+07  3.243449e+07
# mean   1.710749e+06  2.557634e+04       8.351076e+00  5.896975e-01
# std    9.873007e+05  1.409669e+04       7.126671e+00  4.918886e-01
# min    2.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.559430e+05  1.353000e+04       3.000000e+00  0.000000e+00
# 50%    1.711048e+06  2.525600e+04       6.000000e+00  1.000000e+00
# 75%    2.565514e+06  3.793500e+04       1.100000e+01  1.000000e+00
# max    3.421083e+06  4.968800e+04       1.450000e+02  1.000000e+00

# %%
# check for mixed types

for col in df_ords_prior.columns.tolist():
  weird = (df_ords_prior[[col]].applymap(type) != df_ords_prior[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (df_ords_prior[weird]) > 0:
    print (col)

# %%
# check for missing values
df_ords_prior.isnull().sum()
# Out:
# order_id             0
# product_id           0
# add_to_cart_order    0
# reordered            0
# dtype: int64

# %%
#check for duplicates
df_dups = df_ords_prior[df_ords_prior.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
# using an outer join here in order to capture all data
df_merged_large = df_ords_prior.merge(df_ords, on = 'order_id', how = 'outer', indicator = True)

# %%
df_merged_large.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  Unnamed: 0  user_id  \
# 0         2     33120.0                1.0        1.0     3355525   202279
# 1         2     28985.0                2.0        1.0     3355525   202279
# 2         2      9327.0                3.0        0.0     3355525   202279
# 3         2     45918.0                4.0        1.0     3355525   202279
# 4         2     30035.0                5.0        0.0     3355525   202279
#
#    user_order_number  orders_day_of_week  order_hour_of_day  \
# 0                  3                   5                  9
# 1                  3                   5                  9
# 2                  3                   5                  9
# 3                  3                   5                  9
# 4                  3                   5                  9
#
#    days_since_prior_order _merge
# 0                     8.0   both
# 1                     8.0   both
# 2                     8.0   both
# ...

# %%
df_merged_large.describe()
# Out:
#            order_id    product_id  add_to_cart_order     reordered  \
# count  3.264070e+07  3.243449e+07       3.243449e+07  3.243449e+07
# mean   1.710719e+06  2.557634e+04       8.351076e+00  5.896975e-01
# std    9.873085e+05  1.409669e+04       7.126671e+00  4.918886e-01
# min    1.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.558860e+05  1.353000e+04       3.000000e+00  0.000000e+00
# 50%    1.710984e+06  2.525600e+04       6.000000e+00  1.000000e+00
# 75%    2.565490e+06  3.793500e+04       1.100000e+01  1.000000e+00
# max    3.421083e+06  4.968800e+04       1.450000e+02  1.000000e+00
#
#          Unnamed: 0       user_id  user_order_number  orders_day_of_week  \
# count  3.264070e+07  3.264070e+07       3.264070e+07        3.264070e+07
# mean   1.709876e+06  1.029383e+05       1.713856e+01        2.739040e+00
# std    9.864701e+05  5.946686e+04       1.752967e+01        2.090265e+00
# ...

# %%
# delete unnamed and reordered columns
df_merged_large = df_merged_large.drop(columns = ['Unnamed: 0'])

# %%
df_merged_large = df_merged_large.drop(columns = ['reordered'])

# %%
df_merged_large.head()
# Out:
#    order_id  product_id  add_to_cart_order  user_id  user_order_number  \
# 0         2     33120.0                1.0   202279                  3
# 1         2     28985.0                2.0   202279                  3
# 2         2      9327.0                3.0   202279                  3
# 3         2     45918.0                4.0   202279                  3
# 4         2     30035.0                5.0   202279                  3
#
#    orders_day_of_week  order_hour_of_day  days_since_prior_order _merge
# 0                   5                  9                     8.0   both
# 1                   5                  9                     8.0   both
# 2                   5                  9                     8.0   both
# 3                   5                  9                     8.0   both
# 4                   5                  9                     8.0   both

# %%
df_merged_large['_merge'].value_counts()
# Out:
# both          32434489
# right_only      206209
# left_only            0
# Name: _merge, dtype: int64

# %%
.shape
# Out:
# (32640698, 9)

# %%
df_merged_large.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32640698 entries, 0 to 32640697
# Data columns (total 9 columns):
#  #   Column                  Dtype
# ---  ------                  -----
#  0   order_id                int64
#  1   product_id              float64
#  2   add_to_cart_order       float64
#  3   user_id                 int64
#  4   user_order_number       int64
#  5   orders_day_of_week      int64
#  6   order_hour_of_day       int64
#  7   days_since_prior_order  float64
#  8   _merge                  category
# dtypes: category(1), float64(3), int64(5)
# memory usage: 2.2 GB

# %%
#check for duplicates
df_dups2 = df_merged_large[df_merged_large.duplicated()]

# %%
df_dups2
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered, Unnamed: 0, user_id, user_order_number, orders_day_of_week, order_hour_of_day, days_since_prior_order, _merge]
# Index: []

# %%
df_merged_large.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  Unnamed: 0  user_id  \
# 0         2     33120.0                1.0        1.0     3355525   202279
# 1         2     28985.0                2.0        1.0     3355525   202279
# 2         2      9327.0                3.0        0.0     3355525   202279
# 3         2     45918.0                4.0        1.0     3355525   202279
# 4         2     30035.0                5.0        0.0     3355525   202279
#
#    user_order_number  orders_day_of_week  order_hour_of_day  \
# 0                  3                   5                  9
# 1                  3                   5                  9
# 2                  3                   5                  9
# 3                  3                   5                  9
# 4                  3                   5                  9
#
#    days_since_prior_order _merge
# 0                     8.0   both
# 1                     8.0   both
# 2                     8.0   both
# ...

# %%
df_merged_large = df_merged_large.drop(columns = ['Unnamed: 0'])

# %% [markdown]
# # Task

# %% [markdown]
# ## 2. Export the merged file in pickle format as “orders_products_combined.pkl”.

# %%
df_merged_large.to_pickle(os.path.join(path, '02 Data','Prepared Data', '2023-07-28_orders_products_combined.pkl'))
